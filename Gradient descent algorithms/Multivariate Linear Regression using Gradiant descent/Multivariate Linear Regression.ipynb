# %% [markdown]
# # Alternative way to solve this problems.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Create a DataFrame
data = {
    'ram': [2, 4, 6],
    'rom': [10, 32, 64],
    'camera': [8, 8, 12],
    'dis_inch': [5.0, 5.2, 5.5],
    'price': [10000, 20000, 30000]
}

df = pd.DataFrame(data)

# Display basic information
print(df.head())
print(df.tail())
print(df.info())
print(df.shape)
print(df.describe())
print(df.isnull().sum())

# Separate features and target variable
X = df[['ram', 'rom', 'camera', 'dis_inch']]
y = df['price']

# Convert DataFrame to numpy arrays
X = X.values
y = y.values

# Feature scaling (standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add bias term (column of 1's)
X_scaled = np.c_[np.ones(X_scaled.shape[0]), X_scaled]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Initialize and fit the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Predict the price for new data
def predict_price(new_data, model, scaler):
    # Standardize the new data using the scaler fitted on the training data
    new_data_scaled = scaler.transform([new_data])
    # Add bias term
    new_data_scaled = np.insert(new_data_scaled, 0, 1)
    # Predict price
    predicted_price = model.predict([new_data_scaled])
    return predicted_price[0]

# New data for prediction: ram=8, rom=128, camera=12, dis_inch=6.0
new_data = [8, 128, 12, 6.0]
predicted_price = predict_price(new_data, model, scaler)
print("Predicted price for new data:", predicted_price)

# Plotting the predictions vs actual values
plt.scatter(y_test, y_pred, color='red')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
#    ram  rom  camera  dis_inch  price
# 0    2   10       8       5.0  10000
# 1    4   32       8       5.2  20000
# 2    6   64      12       5.5  30000
#    ram  rom  camera  dis_inch  price
# 0    2   10       8       5.0  10000
# 1    4   32       8       5.2  20000
# 2    6   64      12       5.5  30000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ram       3 non-null      int64
#  1   rom       3 non-null      int64
#  2   camera    3 non-null      int64
#  3   dis_inch  3 non-null      float64
#  4   price     3 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 252.0 bytes
# None
# (3, 5)
#        ram        rom     camera  dis_inch    price
# count  3.0   3.000000   3.000000  3.000000      3.0
# mean   4.0  35.333333   9.333333  5.233333  20000.0
# std    2.0  27.153882   2.309401  0.251661  10000.0
# ...

# %% [markdown]
# # using gradient descent algorithams.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Create a DataFrame
data = {
    'ram': [2, 4, 6],
    'rom': [10, 32, 64],
    'camera': [8, 8, 12],
    'dis_inch': [5.0, 5.2, 5.5],
    'price': [10000, 20000, 30000]
}

df = pd.DataFrame(data)

# Display basic information
print(df.head())
print(df.tail())
print(df.info())
print(df.shape)
print(df.describe())
print(df.isnull().sum())

# Separate features and target variable
X = df[['ram', 'rom', 'camera', 'dis_inch']]
y = df['price']

# Convert DataFrame to numpy arrays
X = X.values
y = y.values

# Feature scaling (standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add bias term (column of 1's)
X_scaled = np.c_[np.ones(X_scaled.shape[0]), X_scaled]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Initialize and fit the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Predict the price for new data
def predict_price(new_data, model, scaler):
    # Standardize the new data using the scaler fitted on the training data
    new_data_scaled = scaler.transform([new_data])
    # Add bias term
    new_data_scaled = np.insert(new_data_scaled, 0, 1)
    # Predict price
    predicted_price = model.predict([new_data_scaled])
    return predicted_price[0]

# New data for prediction: ram=8, rom=128, camera=12, dis_inch=6.0
new_data = [8, 128, 12, 6.0]
predicted_price = predict_price(new_data, model, scaler)
print("Predicted price for new data:", predicted_price)

# Plotting the predictions vs actual values
plt.scatter(y_test, y_pred, color='red')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
#    ram  rom  camera  dis_inch  price
# 0    2   10       8       5.0  10000
# 1    4   32       8       5.2  20000
# 2    6   64      12       5.5  30000
#    ram  rom  camera  dis_inch  price
# 0    2   10       8       5.0  10000
# 1    4   32       8       5.2  20000
# 2    6   64      12       5.5  30000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ram       3 non-null      int64
#  1   rom       3 non-null      int64
#  2   camera    3 non-null      int64
#  3   dis_inch  3 non-null      float64
#  4   price     3 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 252.0 bytes
# None
# (3, 5)
#        ram        rom     camera  dis_inch    price
# count  3.0   3.000000   3.000000  3.000000      3.0
# mean   4.0  35.333333   9.333333  5.233333  20000.0
# std    2.0  27.153882   2.309401  0.251661  10000.0
# ...
